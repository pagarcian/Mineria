# %% [markdown]
# <h1><font color='limegreen'><center>Minería de datos</center></font></h1>
# <h2> <center>Tercera entrega</center></h2>
# <center> Paula Camila Garcia Nieto y Nicolle Stefania Quintero Motta</center>

# %% [markdown]
# <h3><font color='limegreen'>Diagrama de entidad-relación</font></h3>

# %%
from IPython.display import Image
Image(url='https://github.com/pagarcian/Mineria/blob/main/sakila-workbench%20(1).png?raw=true', width=800)
# Out:
# <img src="https://github.com/pagarcian/Mineria/blob/main/sakila-workbench%20(1).png?raw=true" width="800"/>

# %% [markdown]
# <h3><font color='limegreen'>Consultas en la consola MariaDB</font></h3>

# %%
Image(url='https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(157).png?raw=true', width=600)
# Out:
# <img src="https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(157).png?raw=true" width="600"/>

# %%
Image(url='https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(158).png?raw=true', width=600)
# Out:
# <img src="https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(158).png?raw=true" width="600"/>

# %%
Image(url='https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(159).png?raw=true', width=600)
# Out:
# <img src="https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(159).png?raw=true" width="600"/>

# %%
Image(url='https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(160).png?raw=true', width=600)
# Out:
# <img src="https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(160).png?raw=true" width="600"/>

# %%
Image(url='https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(161).png?raw=true', width=600)
# Out:
# <img src="https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(161).png?raw=true" width="600"/>

# %%
Image(url='https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(162).png?raw=true', width=600)
# Out:
# <img src="https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(162).png?raw=true" width="600"/>

# %%
Image(url='https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(163).png?raw=true', width=600)
# Out:
# <img src="https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(163).png?raw=true" width="600"/>

# %%
Image(url='https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(164).png?raw=true', width=600)
# Out:
# <img src="https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(164).png?raw=true" width="600"/>

# %%
Image(url='https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(165).png?raw=true', width=600)
# Out:
# <img src="https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(165).png?raw=true" width="600"/>

# %%
Image(url='https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(166).png?raw=true', width=600)
# Out:
# <img src="https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(166).png?raw=true" width="600"/>

# %%
Image(url='https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(167).png?raw=true', width=600)
# Out:
# <img src="https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(167).png?raw=true" width="600"/>

# %%
Image(url='https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(168).png?raw=true', width=600)
# Out:
# <img src="https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(168).png?raw=true" width="600"/>

# %%
Image(url='https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(169).png?raw=true', width=600)
# Out:
# <img src="https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(169).png?raw=true" width="600"/>

# %%
Image(url='https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(170).png?raw=true', width=600)
# Out:
# <img src="https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(170).png?raw=true" width="600"/>

# %%
Image(url='https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(171).png?raw=true', width=600)
# Out:
# <img src="https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(171).png?raw=true" width="600"/>

# %%
Image(url='https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(172).png?raw=true', width=600)
# Out:
# <img src="https://github.com/pagarcian/Mineria/blob/main/Captura%20de%20pantalla%20(172).png?raw=true" width="600"/>

# %% [markdown]
# <h3><font color='limegreen'>Base de datos sqlalchemy</font></h3>

# %%
Image(url='https://github.com/pagarcian/Mineria/blob/main/skalmy1.png?raw=true',width=600)
# Out:
# <img src="https://github.com/pagarcian/Mineria/blob/main/skalmy1.png?raw=true" width="600"/>

# %%
Image(url='https://github.com/pagarcian/Mineria/blob/main/skalmy2.png?raw=true',width=600)
# Out:
# <img src="https://github.com/pagarcian/Mineria/blob/main/skalmy2.png?raw=true" width="600"/>

# %%
Image(url='https://github.com/pagarcian/Mineria/blob/main/skalmy3.png?raw=true',width=600)
# Out:
# <img src="https://github.com/pagarcian/Mineria/blob/main/skalmy3.png?raw=true" width="600"/>

# %%
Image(url='https://github.com/pagarcian/Mineria/blob/main/skalmy4.png?raw=true',width=600)
# Out:
# <img src="https://github.com/pagarcian/Mineria/blob/main/skalmy4.png?raw=true" width="600"/>
